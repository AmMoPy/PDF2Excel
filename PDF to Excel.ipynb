# %%
import tabula
from functools import reduce
import pandas as pd
import numpy as np

# %%
# Convert directly without editing, avaiable outputs are CSV, TSV or JSON
tabula.convert_into("NGO FR.pdf", "NGO_Key_Financial_Ratios.csv", output_format="csv", pages=(1,3,5))

# %%
# Extract tables into pandas, you can just extract and save or edit before saving
# Our example is for a single table split across 3 pages
# We'll extract each piece then merge into a single one
# Two approaches are demonstrated

# 1st approach: Extract each table to a separate dataframe
df1= tabula.read_pdf('NGO FR.pdf', pages=1, lattice=True)
df2= tabula.read_pdf('NGO FR.pdf', pages=3, lattice=True)
df3= tabula.read_pdf('NGO FR.pdf', pages=5, lattice=True)

# 2nd approach: Extract all tables to a single list
# tables_list= tabula.read_pdf('NGO FR.pdf', pages=(1,3,5), lattice=True, multiple_tables=True)

# %%
# Merge 

# 1st approach
dfs_list = [df1, df2, df3]
df_master= reduce(lambda left,right: pd.merge(left,right,how='left',left_index=True, right_index=True), dfs_list)

# 2nd approach
# dfs_list = [tables_list[0], tables_list[1], tables_list[2]]
# df_master= reduce(lambda left,right: pd.merge(left,right,how='left',left_index=True, right_index=True), dfs_list)

# %%
df_master.head()
# Out:
#                        Ratio       Type  \
# 0              Current Ratio  Liquidity
# 1                        NaN          F
# 2  Days of Liquid Net Assets  Liquidity
# 3                        NaN          F
# 4                Quick Ratio  Liquidity
#
#                                              Meaning  \
# 0  Will current resources cover current liabilities?
# 1                                                NaN
# 2  Are there enough liquid resources to cover typ...
# 3                                                NaN
# 4  Will the most liquid assets cover current liab...
#
#                                        Formula  \
# 0                               Current Assets
# 1                                          NaN
# 2                      Unrestricted Net Assets
# 3                                          NaN
# 4  Cash + Marketable Securities +\rReceivables
#
#                                               Result     Best   Unnamed: 3  \
# 0                                Current Liabilities      NaN          > 2
# 1                                                NaN  #DIV/0!          NaN
# 2  Total Expenses - Bad\rDebt Expense -\rDeprecia...      NaN  > 180\rdays
# 3                                                NaN  #DIV/0!          NaN
# 4                                Current Liabilities      NaN          > 1
#
#   Needs Attention  Avrg By Size of NGO
# 0             < 1                  NaN
# 1             NaN                  NaN
# 2       < 90 days                  NaN
# 3             NaN                  NaN
# 4            <.25                  NaN

# %%
# Edit the table, depending on the complexity of your pdf you may need additional edits

# Activate this block of code if you selected 2nd approach
# headers=df_master.iloc[0]
# df_master=df_master[1:].copy()
# df_master.columns=headers
# df_master.reset_index(drop=True, inplace=True)

df_master.drop(columns=['Best', 'Avrg By Size of NGO'], inplace=True)
# both unnamed and np,nan are included here so the code work with either approach selected
df_master.rename(columns={'Formula':'Numerator', 'Result':'Denominator', 'Unnamed: 3':'Benchmark', np.nan:'Benchmark'}, inplace=True)
df_master.loc[8,('Meaning', 'Benchmark', 'Needs Attention')]= 'Monthly expenses covered by liquid assets', 'N/A', 'N/A'
df_master.dropna(axis=0, inplace=True)
df_master.reset_index(drop=True, inplace=True)

# %%
df_master
# Out:
#                         Ratio           Type  \
# 0               Current Ratio      Liquidity
# 1   Days of Liquid Net Assets      Liquidity
# 2                 Quick Ratio      Liquidity
# 3        Days of Cash on Hand      Liquidity
# 4          Months Of Spending      Liquidity
# 5            Operating Margin  Profitability
# 6            Net Asset Growth  Profitability
# 7         Contributions Ratio       Solvency
# 8    Government Revenue Ratio       Solvency
# 9              Debt to Assets       Solvency
# 10     Fundraising Efficiency  Effectiveness
# 11      Program Expense Ratio  Effectiveness
#
#                                               Meaning  \
# 0   Will current resources cover current liabilities?
# 1   Are there enough liquid resources to cover typ...
# 2   Will the most liquid assets cover current liab...
# 3   Is there enough cash to cover typical operatin...
# 4           Monthly expenses covered by liquid assets
# 5   Do typical operating revenues cover typical\ro...
# 6                         Is profitability improving?
# 7   How much does this organization depend on\rdon...
# 8   How much does this organization\rdepend on gov...
# 9   What percentage of assets were\rfinanced with ...
# 10  What does it cost this organization\rto produc...
# 11  What percentage of typical expenses\rare in “c...
#
#                                             Numerator  \
# 0                                      Current Assets
# 1                             Unrestricted Net Assets
# 2         Cash + Marketable Securities +\rReceivables
# 3                        Cash + Marketable Securities
# 4   Current Assets - Current liabilities\r+Temp re...
# 5   Current Year Unrestricted Net Assets\r+ Previo...
# 6   Current Year Total Net Assets -\rPrevious Year...
# 7                                       Contributions
# 8                                 Government Revenues
# 9                            Total Debt (Liabilities)
# 10                                Total Contributions
# 11                                   Program Expenses
#
#                                           Denominator    Benchmark  \
# 0                                 Current Liabilities          > 2
# 1   Total Expenses - Bad\rDebt Expense -\rDeprecia...  > 180\rdays
# 2                                 Current Liabilities          > 1
# 3   Total Expenses - Bad\rDebt Expense -\rDeprecia...    > 90 days
# 4   Total Expenses - Bad\rDebt Expense -\rDeprecia...          N/A
# 5             Unrestricted Revenue\rand Other Support        > +5%
# 6                     Previous Year Total\rNet Assets        > +5%
# 7                                       Total Revenue        > 10%
# 8                                       Total Revenue        < 25%
# 9                      Total unrestricted Net\rAssets          < 1
# 10                               Fundraising Expenses          > 2
# 11                                     Total Expenses        > 75%
#
#    Needs Attention
# 0              < 1
# 1        < 90 days
# 2             <.25
# 3        < 30 days
# 4              N/A
# 5       decreasing
# 6       decreasing
# 7            > 75%
# 8            > 75%
# 9              > 2
# 10             < 1
# 11           < 65%

# %%
# Save dataframe to...
df_master.to_csv('Key_Financial_Ratios_NGO.csv', index_label=None)
df_master.to_excel('Key_Financial_Ratios_NGO.xlsx', index_label=None)
